# %%
def factorial(x):
  if(x==0):
    return 1
  else:
    return (x*factorial(x-1))
print(factorial(5))
# Out:
# 120

# %%
import random
def code_to_debug():
  #import pdb;pdb.set_trace()
  for i in range(10):
    x=random.random()
    factorial(x)

# %%
code_to_debug()
# Out:
# > <ipython-input-12-ca4f51a645db>(4)code_to_debug()
# -> for i in range(10):
# (Pdb) ?
#
# Documented commands (type help <topic>):
# ========================================
# EOF    c          d        h         list      q        rv       undisplay
# a      cl         debug    help      ll        quit     s        unt
# alias  clear      disable  ignore    longlist  r        source   until
# args   commands   display  interact  n         restart  step     up
# b      condition  down     j         next      return   tbreak   w
# break  cont       enable   jump      p         retval   u        whatis
# bt     continue   exit     l         pp        run      unalias  where
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# (Pdb) help c
# c(ont(inue))
#         Continue execution, only stop when a breakpoint is encountered.
# (Pdb) l
#   1  	import random
#   2  	def code_to_debug():
#   3  	  import pdb;pdb.set_trace()
#   4  ->	  for i in range(10):
#   5  	    x=random.random()
#   6  	    factorial(x)
# [EOF]
# (Pdb) n
# > <ipython-input-12-ca4f51a645db>(5)code_to_debug()
# -> x=random.random()
# (Pdb) n
# > <ipython-input-12-ca4f51a645db>(6)code_to_debug()
# -> factorial(x)
# (Pdb) n
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-13-35361d661c6e> in <module>()
# ----> 1 code_to_debug()
#
# <ipython-input-12-ca4f51a645db> in code_to_debug()
#       4   for i in range(10):
#       5     x=random.random()
# ----> 6     factorial(x)
#
# <ipython-input-5-48d749fdfa05> in factorial(x)
#       3     return 1
#       4   else:
# ----> 5     return (x*factorial(x-1))
#       6 print(factorial(5))
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-5-48d749fdfa05> in factorial(x)
#       3     return 1
#       4   else:
# ----> 5     return (x*factorial(x-1))
#       6 print(factorial(5))
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
code_to_debug()
# Out:
# > <ipython-input-12-ca4f51a645db>(4)code_to_debug()
# -> for i in range(10):
# (Pdb) n
# > <ipython-input-12-ca4f51a645db>(5)code_to_debug()
# -> x=random.random()
# (Pdb) n
# > <ipython-input-12-ca4f51a645db>(6)code_to_debug()
# -> factorial(x)
# (Pdb) help step
# s(tep)
#         Execute the current line, stop at the first possible occasion
#         (either in a function that is called or in the current
#         function).
# (Pdb) s
# --Call--
# > <ipython-input-5-48d749fdfa05>(1)factorial()
# -> def factorial(x):
# (Pdb) n
# > <ipython-input-5-48d749fdfa05>(2)factorial()
# -> if(x==0):
# (Pdb) n
# > <ipython-input-5-48d749fdfa05>(5)factorial()
# -> return (x*factorial(x-1))
# (Pdb) print(x)
# 0.6666599187603227
# (Pdb) print(x-1)
# -0.3333400812396773
# (Pdb) s
# --Call--
# > <ipython-input-5-48d749fdfa05>(1)factorial()
# -> def factorial(x):
# (Pdb) quit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-15-35361d661c6e> in <module>()
# ----> 1 code_to_debug()
#
# <ipython-input-12-ca4f51a645db> in code_to_debug()
#       4   for i in range(10):
#       5     x=random.random()
# ----> 6     factorial(x)
#
# <ipython-input-5-48d749fdfa05> in factorial(x)
#       3     return 1
#       4   else:
# ----> 5     return (x*factorial(x-1))
#       6 print(factorial(5))
#
# <ipython-input-5-48d749fdfa05> in factorial(x)
# ----> 1 def factorial(x):
#       2   if(x==0):
#       3     return 1
#       4   else:
#       5     return (x*factorial(x-1))
#
# /usr/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      51             return self.dispatch_line(frame)
#      52         if event == 'call':
# ---> 53             return self.dispatch_call(frame, arg)
#      54         if event == 'return':
#      55             return self.dispatch_return(frame, arg)
#
# /usr/lib/python3.6/bdb.py in dispatch_call(self, frame, arg)
#      84             return self.trace_dispatch
#      85         self.user_call(frame, arg)
# ---> 86         if self.quitting: raise BdbQuit
#      87         return self.trace_dispatch
#      88
#
# BdbQuit:

# %%
def factorial(x):
  if(not isinstance(x,int)):
    print('this method supports only integers')
  if(x==0):
    return 1
  else:
    return (x*factorial(x-1))
print(factorial(5))
# Out:
# 120

# %%
code_to_debug()
# Out:
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# this method supports only integers
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-20-35361d661c6e> in <module>()
# ----> 1 code_to_debug()
#
# <ipython-input-19-1204e5252830> in code_to_debug()
#       4   for i in range(10):
#       5     x=random.random()
# ----> 6     factorial(x)
#
# <ipython-input-16-b083fb0eeaf2> in factorial(x)
#       5     return 1
#       6   else:
# ----> 7     return (x*factorial(x-1))
#       8 print(factorial(5))
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-16-b083fb0eeaf2> in factorial(x)
#       5     return 1
#       6   else:
# ----> 7     return (x*factorial(x-1))
#       8 print(factorial(5))
#
# RecursionError: maximum recursion depth exceeded in comparison
